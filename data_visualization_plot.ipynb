# %% [markdown]
# # Practical Data visualisation
# ### Creating Standard Data Graphics (Functional Plotting)

# %%
import numpy as np
from numpy.random import randn
import pandas as pd
from pandas import Series, DataFrame

import matplotlib.pyplot as plt
from matplotlib import rcParams

# %% [markdown]
# #### Line chart

# %%
x = range(1,10)
y = [1,2,3,4,0,4,3,2,1]
plt.plot(x,y)

# %%
address = 'E:\Jupyter notebook\Linked_in learning DS\WineQT.csv'

wine = pd.read_csv(address)
print(wine.head())
ph = wine['residual sugar']
ph.plot()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                   11                    34   0.9978  3.51       0.56
# 1                   25                    67   0.9968  3.20       0.68
# 2                   15                    54   0.9970  3.26       0.65
# 3                   17                    60   0.9980  3.16       0.58
# 4                   11                    34   0.9978  3.51       0.56
#
#    alcohol  quality  Id
# 0      9.4        5   0
# 1      9.8        5   1
# ...

# %%
df = wine[['fixed acidity','residual sugar','pH']]
df.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Creating Bar chart

# %%
plt.bar(x,y)
# Out:
# <BarContainer object of 9 artists>

# %%
ph.plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
ph.plot(kind="barh")
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Creating Pie chart

# %%
x=[1,2,3,4,0.5]
plt.pie(x)
plt.show()

# %% [markdown]
# ### saving the pie chart

# %%
x=[1,2,3,4,0.5]
plt.pie(x)
plt.savefig('pie_chart.png')
plt.show()

# %% [markdown]
# # Defining elements of a plot
# ### Object Oriented ploting

# %%
# %matplotlib inline  ## This command will generate all plots inline with jupyter notebook
rcParams['figure.figsize'] = 5,4  
## This command will fix the figure size of plots
# Out:
# UsageError: unrecognized arguments: ## This command will generate all plots inline with jupyter notebook

# %% [markdown]
# ### Defining axes, ticks and grids

# %%
x = range(1,10)
y = [1,2,3,4,0,4,3,2,1]

fig = plt.figure()
ax = fig.add_axes([.1,.1,1,1])

ax.plot(x,y)

# %% [markdown]
# # Linear regression code by chat gpt AI

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# Sample input data
X = np.array([[1], [2], [3], [4], [5]])
y = np.array([2, 4, 5, 4, 5])

# Initialize linear regression model
model = LinearRegression()

# Train the model using the input data
model.fit(X, y)

# Make predictions for the input data
y_pred = model.predict(X)

# Create a plot of the actual versus predicted output
plt.scatter(X, y, color='blue')
plt.plot(X, y_pred, color='red')
plt.xlabel('Input')
plt.ylabel('Output')
plt.title('Actual vs. Predicted Output')
plt.show()
